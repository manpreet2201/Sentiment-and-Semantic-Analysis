# %%
pip install dnspython

# %%
from pymongo import MongoClient
from random import randint
import pandas as pd 
import math
import ssl
#Step 1: Connect to MongoDB - Note: Change connection string as needed
client = MongoClient(host=['mongodb+srv://Manpreet:Chahal123@cluster0.mzino.mongodb.net/test'],ssl_cert_reqs=ssl.CERT_NONE,
                     document_class=dict, tz_aware=False, connect=True)
db=client.ReuterDb
print(db)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.mzino.mongodb.net:27017', 'cluster0-shard-00-02.mzino.mongodb.net:27017', 'cluster0-shard-00-00.mzino.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-140kfk-shard-0', ssl=True, ssl_cert_reqs=<VerifyMode.CERT_NONE: 0>), 'ReuterDb')

# %%
dataList=[]
words=["Canada", "rain", "cold", "hot"]
i=0
news=[]
mycol = db["NewsData"]

# %%
for x in mycol.find(): 
    news.append(x["body"])
news=news[:2000]

# %% [markdown]
# # Part 2

# %%
dataList=[]

# %%
import nltk
nltk.download('punkt')
i=0
for sentence in news:
  count=0
  count1=0
  if isinstance(sentence, str):
    tokens = nltk.word_tokenize(sentence)
    for token in tokens:
      count=count+1
      if token=="Canada":
        count1 = count1+1
  if(count1 > 0):
    data={
    "Index":i,
    "Documents":"Article#"+ str(i),
    "Total Words":count,
    "Frequency":count1}
    dataList.append(data)
  i=i+1
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(dataList)
# Out:
# [{'Index': 74, 'Documents': 'Article#74', 'Total Words': 266, 'Frequency': 2}, {'Index': 82, 'Documents': 'Article#82', 'Total Words': 213, 'Frequency': 1}, {'Index': 87, 'Documents': 'Article#87', 'Total Words': 167, 'Frequency': 1}, {'Index': 89, 'Documents': 'Article#89', 'Total Words': 72, 'Frequency': 1}, {'Index': 99, 'Documents': 'Article#99', 'Total Words': 861, 'Frequency': 1}, {'Index': 104, 'Documents': 'Article#104', 'Total Words': 446, 'Frequency': 6}, {'Index': 108, 'Documents': 'Article#108', 'Total Words': 305, 'Frequency': 1}, {'Index': 199, 'Documents': 'Article#199', 'Total Words': 197, 'Frequency': 3}, {'Index': 243, 'Documents': 'Article#243', 'Total Words': 213, 'Frequency': 1}, {'Index': 297, 'Documents': 'Article#297', 'Total Words': 305, 'Frequency': 1}, {'Index': 299, 'Documents': 'Article#299', 'Total Words': 114, 'Frequency': 1}, {'Index': 332, 'Documents': 'Article#332', 'Total Words': 194, 'Frequency': 1}, {'Index': 335, 'Documents': 'Article#335', 'Tota
# ...

# %%
canadaDF = pd.DataFrame(dataList)
canadaDF = canadaDF.sort_values(by=['Frequency'], ascending=False)
canadaDF
# Out:
#     Index     Documents  Total Words  Frequency
# 23    686   Article#686          339          7
# 5     104   Article#104          446          6
# 41   1229  Article#1229          289          4
# 54   1715  Article#1715          251          3
# 7     199   Article#199          197          3
# 12    335   Article#335          351          3
# 18    493   Article#493          358          3
# 0      74    Article#74          266          2
# 16    422   Article#422          939          2
# 47   1438  Article#1438          305          2
# 37   1178  Article#1178           78          2
# 36   1022  Article#1022           98          2
# 32    920   Article#920          434          2
# 29    788   Article#788          463          2
# 22    644   Article#644          115          2
# 56   1822  Article#1822          191          2
# 15    418   Article#418          192          1
# 6     108   Article#108          305          1
# 39   1195  Article#1195           96          1
# ...

# %%
df.to_csv('SemanticAnalysis_Step18_Part2.csv', index = False)

# %% [markdown]
# # Part 3

# %%
for data in dataList:
  data["relativeFrequency"]=data["Frequency"]/data["Total Words"]

# %%
canadaRel = pd.DataFrame(dataList)
canadaRel = canadaRel.sort_values(by=['relativeFrequency'], ascending=False)
canadaRel
# Out:
#     Index     Documents  Total Words  Frequency  relativeFrequency
# 46   1379  Article#1379           30          1           0.033333
# 37   1178  Article#1178           78          2           0.025641
# 49   1511  Article#1511           45          1           0.022222
# 23    686   Article#686          339          7           0.020649
# 36   1022  Article#1022           98          2           0.020408
# 22    644   Article#644          115          2           0.017391
# 7     199   Article#199          197          3           0.015228
# 3      89    Article#89           72          1           0.013889
# 41   1229  Article#1229          289          4           0.013841
# 5     104   Article#104          446          6           0.013453
# 42   1244  Article#1244           79          1           0.012658
# 54   1715  Article#1715          251          3           0.011952
# 21    626   Article#626           85          1           0.011765
# ...

# %%
news[1379]
# Out:
# 'The Bank of Canada said the   U.S. dollar at\nsoon was 1.3053 compared to\n1.3074 dollars yesterday.\n   The pound sterling rates at noon 2.1130  compared to 2.1147\nyesterday.\n   \n'
